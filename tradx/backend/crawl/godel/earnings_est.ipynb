# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://app.godelterminal.com")

# %%
data = driver.execute_async_script("""
    const callback = arguments[arguments.length - 1];
    fetch("https://api.godelterminal.com/api/earnings-estimates?symbol=NVDA")
        .then(resp => resp.json())
        .then(data => callback(data))
        .catch(err => callback({error: err.toString()}));
""")

# %%
import json
print(json.dumps(data, indent=2))
# Out:
# {
#   "earnings_estimate": [
#     {
#       "avg_estimate": 1.01098,
#       "date": "2025-07-31",
#       "high_estimate": 1.1,
#       "low_estimate": 0.85,
#       "number_of_analysts": 36,
#       "period": "next_quarter",
#       "year_ago_eps": 0.68
#     },
#     {
#       "avg_estimate": 4.41233,
#       "date": "2026-01-31",
#       "high_estimate": 5.84,
#       "low_estimate": 3.45,
#       "number_of_analysts": 52,
#       "period": "current_year",
#       "year_ago_eps": 2.99
#     },
#     {
#       "avg_estimate": 5.66678,
#       "date": "2027-01-31",
#       "high_estimate": 7.8,
#       "low_estimate": 4.8,
#       "number_of_analysts": 46,
#       "period": "next_year",
#       "year_ago_eps": 4.41233
#     }
#   ],
#   "meta": {
#     "currency": "USD",
#     "exchange": "NASDAQ",
#     "exchange_timezone": "America/New_York",
#     "mic_code": "XNGS",
#     "name": "Nvidia Corporation",
#     "symbol": "NVDA",
#     "type": "Common Stock"
#   },
#   "status": "ok"
# }

# %%
 https://api.godelterminal.com/api/earnings?symbol=PLTR&startDate=2020-05-04&endDate=2025-05-08

# %%
{
    "meta": {
        "symbol": "PLTR",
        "name": "Palantir Technologies Inc.",
        "currency": "USD",
        "exchange": "NASDAQ",
        "mic_code": "XNGS",
        "exchange_timezone": "America/New_York"
    },
    "earnings": [
        {
            "date": "2025-05-06",
            "time": "After Hours",
            "eps_estimate": 0.13,
            "eps_actual": 0.13,
            "difference": 0,
            "surprise_prc": 0
        },
        {
            "date": "2025-02-04",
            "time": "After Hours",
            "eps_estimate": 0.11,
            "eps_actual": 0.14,
            "difference": 0.03,
            "surprise_prc": 27.27
        },
        {
            "date": "2024-11-05",
            "time": "After Hours",
            "eps_estimate": 0.09,
            "eps_actual": 0.1,
            "difference": 0.01,
            "surprise_prc": 11.11
        },
        {
            "date": "2024-08-06",
            "time": "After Hours",
            "eps_estimate": 0.08,
            "eps_actual": 0.09,
            "difference": 0.01,
            "surprise_prc": 12.5
        },
        {
            "date": "2024-05-07",
            "time": "After Hours",
