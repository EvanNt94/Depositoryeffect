# %%
ISIN = "US1940145022"

# %%
import yfinance as yf

ticker = yf.Ticker(ISIN)
# Out:
# YF deprecation warning: set proxy via new config function: yf.set_config(proxy=proxy)

# %%
ticker.info
# Out:
# {'address1': '2711 Centerville Road',
#  'address2': 'Suite 400',
#  'city': 'Wilmington',
#  'state': 'DE',
#  'zip': '19808',
#  'country': 'United States',
#  'phone': '302 252 9160',
#  'website': 'https://www.enovis.com',
#  'industry': 'Medical Devices',
#  'industryKey': 'medical-devices',
#  'industryDisp': 'Medical Devices',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
# ...

# %%
ticker.financials
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                         -141180900.0
# Tax Rate For Calcs                                          0.21
# Normalized EBITDA                                    191262000.0
# Total Unusual Items                                 -672290000.0
# Total Unusual Items Excluding Goodwill              -672290000.0
# Net Income From Continuing Operation Net Minori...  -828095000.0
# Reconciled Depreciation                              284796000.0
# Reconciled Cost Of Revenue                           807604000.0
# EBITDA                                              -481028000.0
# EBIT                                                -765824000.0
# Net Interest Income                                  -57100000.0
# Interest Expense                                      57100000.0
# Normalized Income                                   -296985900.0
# ...
