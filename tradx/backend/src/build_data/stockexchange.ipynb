# %%
import json
import pandas as pd
import os
import tradx

# %%
tt = {"YALCO":"GRS249003005",
"TELL": "GRS004013009", 
"TITC": "BE0974338700",
"TPEIR": "GRS014003032", 
"TRASTOR": "GRS487003006",
"TRESTATES": "GRS534003009", 
"VIDAVO": "GRS511003006",
"VIO": "BE0974271034", 
"VOSYS": "GRS407183003", 
"XYLEK":"GRS131003006", 
"XYLEP" : "GRS131004004",
"QUEST": "GRS310003009", 
"REALCONS": "GRS522003003", 
"REVOIL": "GRS473003002", 
"SAR": "GRS204003008", 
"SIDMA": "GRS484003009", 
"SOFTWEB": "GRS538003005", 
"SPACE": "GRS402003008", 
"SPIR": "GRS284183001", 
"SUNMEZZ": "CY0200222111", 
"TATT":"GRS001003052", 
"PPA": "GRS470003013", 
"PPC": "GRS434003000",
"PRD": "GRS184003002",
"PREMIA": "GRS497003012", 
"PRODEA": "GRS509003018", 
"PROF": "GRS472003011",
"PROFK": "GRS095003000",
"PVMEZZ": "GRS543003008", 
"QLCO":"GRS543003008", 
"QUAL" :"GRS396003006", 
"OPTIMA": "GRS533003000", 
"OPTRON": "GRS506003003", 
"ORILINA":"GRS535003008", 
"OTOEL":"GRS337003008", 
"PAIR":"GRS275073005", 
"PAP":"GRS065003014", 
"PERF": "GRS505003004", 
"PETRO": "GRS345503007", 
"PLAKR": "GRS326003019", 
"PLAT":"GRS239003007", 
"MOYZK": "GRS054003009", 
"MPITR": "GRS092103001", 
"MYTIL": "GRS393503008", 
"NAKAS": "GRS387503006", 
"NAYP": "GRS265003004", 
"NOVAL": "GRS824003008", 
"OLTH": "GRS427003009",
"OLYMP": "GRS403003007", 
"ONYX": "GRS530003003", 
"OPAP": "GRS419003009", 
"MASTIHA": "GRS500003009",
"MATHIO": "GRS374003002",
"MEDIC": "GRS424003002", 
"MERKO": "GRK014011008", 
"MEVA": "GRS319103008", 
"MIG": "GRS314003013", 
"MIN": "GRS237003009", 
"MODA": "GRS375183001", 
"MOH": "GRS426003000", 
"MOTO": "GRS488003005",
"KYLO": "GRS117123000", 
"KYRI": "GRS295003008", 
"KYSA": "GRS118003003", 
"LAMDA":"GRS245213004", 
"LAMPS": "GRS128003001", 
"LANAC": "GRS047063003", 
"LAVI": "GRS246003008", 
"LEBEK": "GRS090003005", 
"LEBEP": "GRS090004003", 
"LOGISMOS": "GRS343313003",
"INLOT": "GRS343313003", 
"INTEK": "GRS148003015", 
"INTET": "GRS247003007", 
"INTRK": "GRS087003000", 
"KARE": "GRS120003009", 
"KEKR": "GRS070003009", 
"KEPEN": "GRS438003006",
"KORDE": "GRS384003000",
"KRI": "GRS469003024", 
"KTILA": "GRS354003006",
"FRIGO": "GRS346003015",
"GCMEZZ": "CY0200252118",
"GEBKA": "GRS137003000",
"GEKTERNA" : "GRS145003000",
"HAIDE": "GRS350263000",
"HTO": "GRS260333000",
"IATR": "GRS147233001",
"IKTIN" : "GRS372003004",
"ILYDA": "GRS475003018", 
"INLIF" :"GRS805003001",
"EVR" : "GRS474003001",
"EVROF" : "GRS385113006",
"EX" :"GRS501003008",
"EXAE" :"GRS395363005",
"EYAPS" : "GRS428003008",
"EYDAP": "GRS359353000",
"FAIS": "GRS542003009", 
"FLEXO": "GRS259003002",
"FOODL" : "GRS510003015",
"FOYRK": "GRS096003009", 
"ELHA": "GRS281003004",
"ELIN": "GRS477003008",
"ELLAKTOR": "GRS191213008", 
"ELPE": "GRS298343005",
"ELSTR": "GRS088003017",
"ELTON":"GRS397003005",
"EPIL" :"GRS045003001",
"ETE": "GRS003003035",
"EUROB": "GRS323003012",
"EUROC" :"GRS439003005",
"DAIOS": "GRS382073005",
"DIMAND": "GRS525003000",
"DOMIK" : "GRS364253005",
"DOPPLER": "GRS502003007",
"DOTSOFT": "GRS531003002",
"DROME": "GRS412503005",
"DUR": "GRS392193009",
"EEE" : "CH0198251305",
"EKTER" : "GRS222213001",
"ELBE": "GRS240003012",
"BIOSK" : "GRS084003011",
"BIOT": "GRS135003002",
"BLEKEDROS" : "GRS524003001",
"BOCHGR": "IE00BD5B1Y92",
"BRIQ" :"GRS517003000",
"CAIROMEZ": "CY0109232112",
"CENER" : "BE0974303357",
"CENTR" : "GRS449003003", 
"CNLCAP" : "GRS520003005",
"CPI" : "GRS413313008",
"ANDRO" : "GRS433003019",
"ASCO" :  "GRS404003006",
"ASTAK" : "GRS331043000",
"ATEK" : "GRS340263003",
"ATRUST" :"GRS504003021",
"ATTICA" : "GRS144003001",
"AVAX":"GRS213213002",
"AVE" :"GRS489003004", 
"BELA" : "GRS282183003",
"BIOKA": "GRS165063009",
"AAAK" : "GRS059063008",
"ACAG" : "AT0000A325L0",
"ADMIE": "GRS518003009",
"AEGN": "GRS495003006",
"AEM" : "GRS541003000",
"AIA": "GRS536003007",
"AKRIT": "GRS373173004",
"AKTR": "GRS432003028",
"ALMY" : "GRS289103004",
"ALPHA": "GRS015003007"}

# %%
foreign = {
    "ΤΡΑΣΤΟΡ": "GRS487003006", 
    "TITC": "BE0974338700",
  "ΑΒΑΞ": "GRS213213002",
  "ΑΔΜΗΕ": "GRS518003009",
  "ΑΚΡΙΤ": "GRS373173004",
  "ΑΛΜΥ": "GRS289103004",
  "ΑΡΑΙΓ": "GRS495003006",
  "ΑΤΕΚ": "GRS340263003",
  "ΚΟΡΔΕ": "GRS384003000",
  "ΜΙΝ": "GRS237003009",
  "ΣΠΥΡ": "GRS284183001",
  "ΒΙΟΚΑ": "GRS165063009",
  "ΒΙΟΤ": "GRS135003002",
  "ΒΟΣΥΣ": "GRS407183003",
  "ΓΕΒΚΑ": "GRS137003000",
  "ΓΕΚΤΕΡΝΑ": "GRS145003000",
  "ΣΑΡ": "GRS204003008",
  "ΔΑΑ": "GRS536003007",
  "ΔΑΙΟΣ": "GRS382073005",
  "ΔΕΗ": "GRS434003000",
  "ΔΟΜΙΚ": "GRS364253005",
  "ΔΟΥΡΟ": "GRS392193009",
  "EVR": "GRS474003001",
  "ΑΑΑΚ": "GRS059063008",
  "ΕΒΡΟΦ": "GRS385113006",
  "ΕΚΤΕΡ": "GRS222213001",
  "ΕΛΒΕ": "GRS240003012",
  "ΕΛΙΝ": "GRS477003008",
  "ΕΛΛΑΚΤΩΡ": "GRS191213008",
  "ΕΛΣΤΡ": "GRS088003017",
  "ΕΛΤΟΝ": "GRS397003005",
  "ΕΛΧΑ": "GRS281003004",
  "ΙΑΤΡ": "GRS147233001",
  "ΙΚΤΙΝ": "GRS372003004",
  "ΙΛΥΔΑ": "GRS475003018",
  "ΙΝΛΙΦ": "GRS805003001",
  "ΙΝΛΟΤ": "GRS343313003",
  "ΙΝΤΕΤ": "GRS247003007",
  "ΙΝΤΚΑ": "GRS087003000",
  "ΞΥΛΚ": "GRS131003006",
  "ΞΥΛΠ": "GRS131004004",
  "ΚΑΡΕΛ": "GRS120003009",
  "ΚΕΚΡ": "GRS070003009",
  "ΚΡΙ": "GRS469003024",
  "ΚΤΗΛΑ": "GRS354003006",
  "ΚΥΡΙΟ": "GRS295003008",
  "ΝΑΥΠ": "GRS265003004",
  "ΣΑΡΑΝ": "GRS118003003",
  "ΛΑΜΨΑ": "GRS128003001",
  "ΛΑΝΑΚ": "GRS047063003",
  "ΚΕΠΕΝ": "GRS438003006",
  "ΜΑΘΙΟ": "GRS374003002",
  "ΜΟΗ": "GRS426003000",
  "ΜΠΛΕΚΕΔΡΟΣ": "GRS524003001",
  "ΜΠΤΚ": "GRS092103001",
  "NOVAL": "GRS824003008",
  "ΛΕΒΚ": "GRS090003005",
  "ΛΕΒΠ": "GRS090004003",
  "ΥΑΛΚΟ": "GRS249003005",
  "ΜΟΝΤΑ": "GRS375183001",
  "ΝΑΚΑΣ": "GRS387503006",
  "ΝΤΟΠΛΕΡ": "GRS502003007",
  "ONYX": "GRS530003003",
  "ΟΛΘ": "GRS427003009",
  "ΟΛΠ": "GRS470003013",
  "ΟΠΑΠ": "GRS419003009",
  "ΟΠΤΡΟΝ": "GRS506003003",
  "ΟΤΕ": "GRS260333000",
  "ΔΡΟΜΕ": "GRS412503005",
  "ΠΑΠ": "GRS065003014",
  "ΠΕΙΡ": "GRS014003032",
  "ΠΕΤΡΟ": "GRS345503007",
  "ΠΛΑΘ": "GRS239003007",
  "ΠΛΑΚΡ": "GRS326003019",
  "ΠΡΔ": "GRS184003002",
  "ΠΡΟΝΤΕΑ": "GRS509003018",
  "ΡΕΒΟΙΛ": "GRS473003002",
  "ΣΙΔΜΑ": "GRS484003009",
  "ΤΖΚΑ": "GRS095003000",
  "OPTIMA": "GRS533003000",
  "ΕΛΛ": "GRS004013009",
  "ΟΛΥΜΠ": "GRS403003007",
  "ΦΑΙΣ": "GRS542003009",
  "ΦΟΥΝΤΛ": "GRS510003015",
  "ΧΑΙΔΕ": "GRS350263000",
  "ΕΠΙΛΚ": "GRS045003001",
  "ΕΣΥΜΒ": "GRS439003005",
  "ΕΤΕ": "GRS003003035",
  "ΕΥΑΠΣ": "GRS428003008",
  "ΕΥΔΑΠ": "GRS359353000",
  "ΕΧΑΕ": "GRS395363005",
  "ΜΟΤΟ": "GRS488003005",
  "ΜΟΥΖΚ": "GRS054003009",
  "ΠΑΙΡ": "GRS275073005",
  "ΤΡΕΣΤΑΤΕΣ": "GRS534003009",
  "ΒΙΝΤΑ":"GRS511003006",
  "ΒΙΟ":"BE0974271034",
  "ΚΟΥΕΣ":"GRS310003009",
  "REALCONS": "GRS522003003",
  "SOFTWEB":"GRS538003005",
  "ΣΠΕΙΣ":"GRS402003008",
  "ΣΑΝΜΕΖΖ":"CY0200222111",
  "ΑΤΤ": "GRS001003052",
  "ΠΡΕΜΙΑ":"GRS497003012",
  "ΠΡΟΦ": "GRS472003011",
  "ΦΒΜΕΖΖ":"GRS543003008",
  "ΚΟΥΑΛ":"GRS396003006",
  "ΟΡΙΛΙΝΑ": "GRS535003008",
  "ΟΤΟΕΛ":"GRS337003008",
  "ΠΕΡΦ":"GRS505003004",
  "ΜΥΤΙΛ":"GRS393503008",
  "ΜΑΣΤΙΧΑ":"GRS500003009",
  "ΜΕΝΤΙ":"GRS424003002",
  "ΜΕΡΚΟ":"GRK014011008",
  "ΜΕΒΑ":"GRS319103008",
  "ΜΙΓ": "GRS314003013",
  "ΛΟΥΛΗ":"GRS117123000",
  "ΛΑΜΔΑ":"GRS245213004",
  "ΛΑΒΙ":"GRS246003008",
  "ΙΝΤΕΚ":"GRS148003015",
  "ΦΡΙΓΟ":"GRS346003015",
  "ΓΚΜΕΖΖ":"CY0200252118",
  "ΕΧ": "GRS501003008",
  "ΦΛΕΞΟ": "GRS259003002",
  "ΦΡΛΚ": "GRS096003009",
  "ΕΛΠΕ":"GRS298343005",
  "ΕΥΡΩΒ":"GRS323003012",
  "DIMAND":"GRS525003000",
  "ΝΤΟΤΣΟΦΤ":"GRS531003002",
  "ΕΕΕ": "CH0198251305",
  "ΒΙΟΣΚ":"GRS084003011",
  "BOCHGR":"IE00BD5B1Y92",
  "ΜΠΡΙΚ":"GRS517003000",
  "ΚΑΙΡΟΜΕΖ":"CY0109232112",
  "CENER":"BE0974303357",
  "ΣΕΝΤΡ":"GRS449003003",
  "CNLCAP":"GRS520003005",
  "ΣΠΙ":"GRS413313008",
  "ΑΝΔΡΟ":"GRS433003019",
  "ΑΣΚΟ": "GRS404003006",
  "ΑΣΤΑΚ":"GRS331043000",
  "ΑΤΡΑΣΤ":"GRS331043000",
  "ΑΤΡΑΣΤ":"GRS504003021",
  "ΑΤΤΙΚΑ":"GRS144003001",
  "ΑΒΕ":"GRS489003004",
  "ΜΠΕΛΑ":"GRS282183003",
  "ACAG":"AT0000A325L0",
  "AEM":"GRS541003000",
  "AKTR":"GRS432003028",
  "ΑΛΦΑ":"GRS015003007"
}
isin_to_ticker = {v: k for k, v in foreign.items()}

# %%
from iso3166 import countries

def get_country_from_isin(isin):
    try:
        return countries.get(isin[:2]).name
    except KeyError:
        return "Unknown"

# %%
tickers = tt.keys()

# %%
import tradx.backend.src.worker.db.StockExchangeDBWorker as SXW
import yfinance as yf
from datetime import datetime
import time

worker = SXW.StockExchangeDBWorker()
for ticker in tickers:
    time.sleep(1)
    yft = yf.Ticker(ticker+".AT")
    i = yft.info
    isin = tt[ticker]
    dd = {}
    dd["ticker"] = ticker+".AT"
    dd["isin"] = isin
    dd["name"] = i.get("longName", "No Name")
    dd["country"] = get_country_from_isin(isin=isin)
    dd["country_hq"] = i.get("country", "No Country")
    dd["currency"] = i.get("currency", "No Currency")
    dd["last_updated"] = datetime.now().isoformat()
    dd["ticker_local"] = isin_to_ticker[isin]
    dd["website"] = f"https://www.athexgroup.gr/en/market-data/instruments/stocks/{ticker}"
    worker.insert_or_update_ticker("AT", dd)
