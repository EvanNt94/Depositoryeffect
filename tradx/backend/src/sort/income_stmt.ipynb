# %%
import yfinance as yf
import pandas

TICKER = "SRPT"
ticker = yf.Ticker(TICKER)
h = ticker.income_stmt
print(h)
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                            -768124.0
# Tax Rate For Calcs                                         0.098
# Normalized EBITDA                                    324727000.0
# Total Unusual Items                                   -7838000.0
# Total Unusual Items Excluding Goodwill                -7838000.0
# Net Income From Continuing Operation Net Minori...   235239000.0
# Reconciled Depreciation                               37724000.0
# Reconciled Cost Of Revenue                           283780000.0
# EBITDA                                               316889000.0
# EBIT                                                 279165000.0
# Net Interest Income                                   53376000.0
# Interest Expense                                      18391000.0
# Interest Income                                       71767000.0
# ...

# %%
ticker.info
ticker.calendar
ticker.analyst_price_targets
ticker.quarterly_income_stmt
ticker.history(period='1mo')
ticker.option_chain(ticker.options[0]).calls
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[6], line 2
#       1 ticker.info
# ----> 2 ticker.calendar
#       3 ticker.analyst_price_targets
#       4 ticker.quarterly_income_stmt
#
# File ~/anaconda3/envs/trade/lib/python3.12/site-packages/yfinance/ticker.py:170, in Ticker.calendar(self)
#     165 @property
#     166 def calendar(self) -> dict:
#     167     """
#     168     Returns a dictionary of events, earnings, and dividends for the ticker
#     169     """
# --> 170     return self.get_calendar()
#
# File ~/anaconda3/envs/trade/lib/python3.12/site-packages/yfinance/base.py:189, in TickerBase.get_calendar(self, proxy)
#     187 def get_calendar(self, proxy=None) -> dict:
#     188     self._quote.proxy = proxy or self.proxy
# --> 189     return self._quote.calendar
#
# ...

# %%
ticker.income_stmt
# Out:
#                                                       2024-12-31  \
# Tax Effect Of Unusual Items                            -768124.0
# Tax Rate For Calcs                                         0.098
# Normalized EBITDA                                    324727000.0
# Total Unusual Items                                   -7838000.0
# Total Unusual Items Excluding Goodwill                -7838000.0
# Net Income From Continuing Operation Net Minori...   235239000.0
# Reconciled Depreciation                               37724000.0
# Reconciled Cost Of Revenue                           283780000.0
# EBITDA                                               316889000.0
# EBIT                                                 279165000.0
# Net Interest Income                                   53376000.0
# Interest Expense                                      18391000.0
# Interest Income                                       71767000.0
# ...
