# %%
import json 
with open("/Users/a2/code/fin/trade/data/NASDAQ/symbols.json", "r") as f:
    s = json.load(f)

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt
import pandas as pd, os
from pandas import DataFrame
ts = TimeSeries(key='DEFKZ1GRUJCJADBJ', output_format='pandas')
num_folder = "/Users/a2/code/fin/trade/data/numbers"
for ticker in s:
    data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
    data.to_csv(os.path.join(num_folder, ticker))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       6 num_folder = "/Users/a2/code/fin/trade/data/numbers"
#       7 for ticker in s:
# ----> 8     data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
#       9     data.to_csv(os.path.join(num_folder, ticker))
#
# File ~/anaconda3/lib/python3.11/site-packages/alpha_vantage/alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
#     220     if 'json' in self.output_format.lower() or 'pandas' \
#     221             in self.output_format.lower():
#     222         if data_key is not None:
#
# ...

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='DEFKZ1GRUJCJADBJ', output_format='pandas')
data, meta_data = ts.get_intraday(symbol='MSFT',interval='1min', outputsize='full')
data['4. close'].plot()
plt.title('Intraday Times Series for the MSFT stock (1 min)')
plt.show()
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
def get(symbol:str, interval:str="1min")->pd.DataFrame:
    ts = TimeSeries(key='DEFKZ1GRUJCJADBJ', output_format='pandas')
    data, meta_data = ts.get_intraday(symbol=symbol,interval=interval, outputsize='full')
    return data

# %%
import os, json
root_data_dir = "/Users/a2/code/fin/trade/data"
fra = os.path.join(root_data_dir, "FRA")
with open(os.path.join(fra, "symbols.json"), "r") as f:
    sym = json.load(f)
for symbol in sym:
    get(symbol).to_csv(os.path.join(fra, symbol))

# %%
import os, json
root_data_dir = "/Users/a2/code/fin/trade/data"
fra = os.path.join(root_data_dir, "NASDAQ")
with open(os.path.join(fra, "symbols.json"), "r") as f:
    sym = json.load(f)
fra = os.path.join(fra, "040724")
for symbol in sym:
    get(symbol).to_csv(os.path.join(fra, symbol))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       6 fra = os.path.join(fra, "040724")
#       7 for symbol in sym:
# ----> 8     get(symbol).to_csv(os.path.join(fra, symbol))
#
# Cell In[5], line 5, in get(symbol, interval)
#       3 def get(symbol:str, interval:str="1min")->pd.DataFrame:
#       4     ts = TimeSeries(key='DEFKZ1GRUJCJADBJ', output_format='pandas')
# ----> 5     data, meta_data = ts.get_intraday(symbol=symbol,interval=interval, outputsize='full')
#       6     return data
#
# File ~/anaconda3/lib/python3.11/site-packages/alpha_vantage/alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
# ...
